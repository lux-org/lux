# %%
import lux
import pandas as pd
from vega_datasets import data
from lux.vis.Vis import Vis
from lux.vis.VisList import VisList

# lux.config.default_display = "lux"
from IPython.core.debugger import set_trace

df = data.cars()
# df = pd.read_csv("TEST_data.csv")

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.data_type["Cylinders"]
# Out:
# 'nominal'

# %%
# quant single
df[(df.Origin.isin(["Japan", "USA"])) & (df.Cylinders < 6) & (df.Miles_per_Gallon > 29)]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
m = (df.Miles_per_Gallon < 25) & (df.Weight_in_lbs < 3500) & (df.Origin == "Japan")

# %%
import altair as alt 
tf_scale = alt.Scale(domain = [True, False], 
                    range = ["steelblue", "#ededed"])

def plot_filter_count(ldf, mask):
    """
    For filtered dfs, plot the count of columns compared to count of unfiltered df
    """

    ldf = ldf.copy()
    ldf["filt_mask"] = mask

    chart = alt.Chart(ldf).mark_bar(size=75).encode(
        x = alt.X("count()", title="Filtered Data Count"),
        color = alt.Color("filt_mask", 
                           scale = tf_scale,
                           legend = None),
        order=alt.Order('filt_mask', sort='descending')
        ).properties(height=150, width=150)
    
    # DONT use interactive for this chart, it breaks for some reason

    return chart

def plot_filter(ldf, cols, mask):
    """
    data_source = df
    col_filters = [ColFilter, ...]
    """
    ldf = ldf.copy()
    ldf["filt_mask"] = mask

    chart = None
    
    if len(cols) == 1 and cols[0] in ldf.data_type:
        this_col = cols[0]

        x_d_type = ldf.data_type[this_col]
        _bin = (x_d_type == "quantitative")
        
        chart = alt.Chart(ldf).mark_bar().encode(
          x= alt.X(this_col, type=x_d_type, bin=_bin),
          y=f"count({this_col}):Q",
          color= alt.Color("filt_mask", scale= tf_scale, title="Is Filtered?" )
        )
        
    elif len(cols) >= 2 and (cols[0] in ldf.data_type) and (cols[1] in ldf.data_type): # this looks bad when both are categorical
        x_d_type = ldf.data_type[cols[0]]
        y_d_type = ldf.data_type[cols[1]]
        x_bin = (x_d_type == "quantitative")
        y_bin = (y_d_type == "quantitative")
        
        bg = alt.Chart(ldf).mark_circle(color="#ededed").encode(
          x= alt.X(cols[0], type=x_d_type, bin=x_bin),
          y= alt.Y(cols[1], type=y_d_type, bin=y_bin),
          size=alt.Size("count()", legend=None),
        )
        
        filt_chart = alt.Chart(ldf).mark_circle(color="steelblue").transform_filter(
            (alt.datum.filt_mask == True)
        ).encode(
          x= alt.X(cols[0], type=x_d_type, bin=x_bin),
          y= alt.Y(cols[1], type=y_d_type, bin=y_bin),
          size=alt.Size("count()", legend=None),
        )
        
        chart = bg + filt_chart
    
    if chart:
        chart = chart.interactive()
    
    return chart

# %%
plot_filter(df, ["Weight_in_lbs", "Origin"], m).properties(height=150, width=150)
# Out:
# alt.LayerChart(...)

# %%
plot_filter(df, ["Displacement", "Miles_per_Gallon"], m)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Filter

# %%
df[(df.Origin == "USA")]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df_2.history

# %%
id(df_2._parent_df)

# %%
df_2 = df.describe()

# %%
df[(df.Cylinders > 5)]

# %%
df.groupby("Origin").agg(
{"Miles_per_Gallon": "mean", "Horsepower": "median"}
)

# %% [markdown]
# # New col

# %%
df

# %%
df["new_col"] = df.Cylinders * 11

# %%
df.history

# %% [markdown]
# # Query

# %%
filt_df_2 = df.query("Cylinders > 4 & Origin == 'USA'")

# %%
filt_df_2

# %%
filt_df_2._history

# %%
df._history

# %%
filt_df._history._events[-1].kwargs["filt_key"]

# %%
len(df)

# %% [markdown]
# # For refs

# %%
def run():
    set_trace()
    r = df[(df.Cylinders > 3) & (df.Origin == "USA") & (df.Miles_per_Gallon < 15)]
    return r

# %%
r = run()

# %% [markdown]
# # IDS
#
# In the box function thing
# ipdb>  id(self) frame
# 140413758896016
# ipdb>  id(self._history) frame
# 140413758896064
# ipdb>  id(s)
# 140414833158128
# ipdb>  id(s._history)
# 140414833258400
#
# In finalize
# self is the series, other is the frame

# %%
df._history

# %%
l = df["Cylinders"]
l = df["Acceleration"]
l = df["Cylinders"]

# df_2 = df[["Origin"]]

# %%
df.Origin.unique()
