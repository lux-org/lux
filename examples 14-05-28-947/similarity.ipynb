# %%
import pandas as pd
import lux
from lux.vis.Clause import Clause
from lux.utils.utils import get_filter_specs

lux.config.default_display = "lux"
lux.config.plotting_backend = "matplotlib"

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/airbnb_nyc.csv")
df['last_review'] = pd.to_datetime(df['last_review'], format='%Y-%m-%d')

df.set_intent([lux.Clause("price",channel="x"), 
               lux.Clause("availability_365",channel="y"), 
               lux.Clause("longitude")])
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df = pd.read_csv("../lux/data/car.csv")
df["Year"] = pd.to_datetime(df["Year"], format='%Y') # change pandas dtype for the column "Year" to datetype

# df.set_intent([lux.Clause("Displacement",channel="x"),
#               lux.Clause("Origin",channel="y")])
df.set_intent([lux.Clause("Acceleration",channel="x"), 
               lux.Clause("Horsepower", channel="y"), 
               lux.Clause("Weight")])

# df.current_vis[0].mark
# len(get_filter_specs(df.intent))
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
vis = df.exported[0]

# %%
print(vis.to_Altair())
# Out:
# import altair as alt
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import nan

df = pd.DataFrame({'Weight': {0: 3504, 1: 3693, 2: 3436, 3: 3433, 4: 3449, 5: 4341, 6: 4354, 7: 4312, 8: 4425, 9: 3850, 10: 3563, 11: 3609, 12: 3761, 13: 3086, 14: 2372, 15: 2833, 16: 2774, 17: 2587, 18: 2130, 19: 1835, 20: 2672, 21: 2430, 22: 2375, 23: 2234, 24: 2648, 25: 4615, 26: 4376, 27: 4382, 28: 4732, 29: 2130, 30: 2264, 31: 2228, 32: 2634, 33: 3439, 34: 3329, 35: 3302, 36: 3288, 37: 4209, 38: 4464, 39: 4154, 40: 4096, 41: 4955, 42: 4746, 43: 5140, 44: 2962, 45: 2408, 46: 3282, 47: 3139, 48: 2220, 49: 2123, 50: 2074, 51: 2065, 52: 1773, 53: 1613, 54: 1834, 55: 1955, 56: 2278, 57: 2126, 58: 2254, 59: 2408, 60: 2226, 61: 4274, 62: 4385, 63: 4135, 64: 4129, 65: 3672, 66: 4633, 67: 4502, 68: 4456, 69: 4422, 70: 2330, 71: 3892, 72: 4098, 73: 4294, 74: 4077, 75: 2933, 76: 2511, 77: 2979, 78: 2189, 79: 2395, 80: 2288, 81: 2506, 82: 2164, 83: 2100, 84: 4100, 85: 3672, 86: 3988, 87: 4042, 88: 3777, 89: 4952, 90: 4464, 91: 4363, 92: 4237, 93: 4735, 94: 4951, 95: 3821, 96: 3121, 97: 3278, 98: 2945, 99: 3021, 100: 2904, 101: 1950, 102: 4997, 103: 4906, 104: 4654, 105: 4499, 106: 2789, 107: 2279, 108: 2401, 109: 2379, 110: 2124, 111: 2310, 112: 2472, 113: 2265, 114: 4082, 115: 4278, 116: 1867, 117: 2158, 118: 2582, 119: 2868, 120: 3399, 121: 2660, 122: 2807, 123: 3664, 124: 3102, 125: 2901, 126: 3336, 127: 1950, 128: 2451, 129: 1836, 130: 2542, 131: 3781, 132: 3632, 133: 3613, 134: 4141, 135: 4699, 136: 4457, 137: 4638, 138: 4257, 139: 2219, 140: 1963, 141: 2300, 142: 1649, 143: 2003, 144: 2125, 145: 2108, 146: 2246, 147: 2489, 148: 2391, 149: 2000, 150: 3264, 151: 3459, 152: 3432, 153: 3158, 154: 4668, 155: 4440, 156: 4498, 157: 4657, 158: 3907, 159: 3897, 160: 3730, 161: 3785, 162: 3039, 163: 3221, 164: 3169, 165: 2171, 166: 2639, 167: 2914, 168: 2592, 169: 2702, 170: 2223, 171: 2545, 172: 2984, 173: 1937, 174: 3211, 175: 2694, 176: 2957, 177: 2945, 178: 2671, 179: 1795, 180: 2464, 181: 2220, 182: 2572, 183: 2255, 184: 2202, 185: 4215, 186: 4190, 187: 3962, 188: 4215, 189: 3233, 190: 3353, 191: 3012, 192: 3085, 193: 2035, 194: 2164, 195: 1937, 196: 1795, 197: 3651, 198: 3574, 199: 3645, 200: 3193, 201: 1825, 202: 1990, 203: 2155, 204: 2565, 205: 3150, 206: 3940, 207: 3270, 208: 2930, 209: 3820, 210: 4380, 211: 4055, 212: 3870, 213: 3755, 214: 2045, 215: 2155, 216: 1825, 217: 2300, 218: 1945, 219: 3880, 220: 4060, 221: 4140, 222: 4295, 223: 3520, 224: 3425, 225: 3630, 226: 3525, 227: 4220, 228: 4165, 229: 4325, 230: 4335, 231: 1940, 232: 2740, 233: 2265, 234: 2755, 235: 2051, 236: 2075, 237: 1985, 238: 2190, 239: 2815, 240: 2600, 241: 2720, 242: 1985, 243: 1800, 244: 1985, 245: 2070, 246: 1800, 247: 3365, 248: 3735, 249: 3570, 250: 3535, 251: 3155, 252: 2965, 253: 2720, 254: 3430, 255: 3210, 256: 3380, 257: 3070, 258: 3620, 259: 3410, 260: 3425, 261: 3445, 262: 3205, 263: 4080, 264: 2155, 265: 2560, 266: 2300, 267: 2230, 268: 2515, 269: 2745, 270: 2855, 271: 2405, 272: 2830, 273: 3140, 274: 2795, 275: 3410, 276: 1990, 277: 2135, 278: 3245, 279: 2990, 280: 2890, 281: 3265, 282: 3360, 283: 3840, 284: 3725, 285: 3955, 286: 3830, 287: 4360, 288: 4054, 289: 3605, 290: 3940, 291: 1925, 292: 1975, 293: 1915, 294: 2670, 295: 3530, 296: 3900, 297: 3190, 298: 3420, 299: 2200, 300: 2150, 301: 2020, 302: 2130, 303: 2670, 304: 2595, 305: 2700, 306: 2556, 307: 2144, 308: 1968, 309: 2120, 310: 2019, 311: 2678, 312: 2870, 313: 3003, 314: 3381, 315: 2188, 316: 2711, 317: 2542, 318: 2434, 319: 2265, 320: 2110, 321: 2800, 322: 2110, 323: 2085, 324: 2335, 325: 2950, 326: 3250, 327: 1850, 328: 2145, 329: 1845, 330: 2910, 331: 2420, 332: 2500, 333: 2290, 334: 2490, 335: 2635, 336: 2620, 337: 2725, 338: 2385, 339: 1755, 340: 1875, 341: 1760, 342: 2065, 343: 1975, 344: 2050, 345: 1985, 346: 2215, 347: 2045, 348: 2380, 349: 2190, 350: 2210, 351: 2350, 352: 2615, 353: 2635, 354: 3230, 355: 3160, 356: 2900, 357: 2930, 358: 3415, 359: 3725, 360: 3060, 361: 3465, 362: 2605, 363: 2640, 364: 2395, 365: 2575, 366: 2525, 367: 2735, 368: 2865, 369: 1980, 370: 2025, 371: 1970, 372: 2125, 373: 2125, 374: 2160, 375: 2205, 376: 2245, 377: 1965, 378: 1965, 379: 1995, 380: 2945, 381: 3015, 382: 2585, 383: 2835, 384: 2665, 385: 2370, 386: 2950, 387: 2790, 388: 2130, 389: 2295, 390: 2625, 391: 2720}, 'Displacement': {0: 307.0, 1: 350.0, 2: 318.0, 3: 304.0, 4: 302.0, 5: 429.0, 6: 454.0, 7: 440.0, 8: 455.0, 9: 390.0, 10: 383.0, 11: 340.0, 12: 400.0, 13: 455.0, 14: 113.0, 15: 198.0, 16: 199.0, 17: 200.0, 18: 97.0, 19: 97.0, 20: 110.0, 21: 107.0, 22: 104.0, 23: 121.0, 24: 199.0, 25: 360.0, 26: 307.0, 27: 318.0, 28: 304.0, 29: 97.0, 30: 140.0, 31: 113.0, 32: 232.0, 33: 225.0, 34: 250.0, 35: 250.0, 36: 232.0, 37: 350.0, 38: 400.0, 39: 351.0, 40: 318.0, 41: 383.0, 42: 400.0, 43: 400.0, 44: 258.0, 45: 140.0, 46: 250.0, 47: 250.0, 48: 122.0, 49: 116.0, 50: 79.0, 51: 88.0, 52: 71.0, 53: 72.0, 54: 97.0, 55: 91.0, 56: 113.0, 57: 97.5, 58: 97.0, 59: 140.0, 60: 122.0, 61: 350.0, 62: 400.0, 63: 318.0, 64: 351.0, 65: 304.0, 66: 429.0, 67: 350.0, 68: 350.0, 69: 400.0, 70: 70.0, 71: 304.0, 72: 307.0, 73: 302.0, 74: 318.0, 75: 121.0, 76: 121.0, 77: 120.0, 78: 96.0, 79: 122.0, 80: 97.0, 81: 120.0, 82: 98.0, 83: 97.0, 84: 350.0, 85: 304.0, 86: 350.0, 87: 302.0, 88: 318.0, 89: 429.0, 90: 400.0, 91: 351.0, 92: 318.0, 93: 440.0, 94: 455.0, 95: 360.0, 96: 225.0, 97: 250.0, 98: 232.0, 99: 250.0, 100: 198.0, 101: 97.0, 102: 400.0, 103: 400.0, 104: 360.0, 105: 350.0, 106: 232.0, 107: 97.0, 108: 140.0, 109: 108.0, 110: 70.0, 111: 122.0, 112: 155.0, 113: 98.0, 114: 350.0, 115: 400.0, 116: 68.0, 117: 116.0, 118: 114.0, 119: 121.0, 120: 318.0, 121: 121.0, 122: 156.0, 123: 350.0, 124: 198.0, 125: 232.0, 126: 250.0, 127: 79.0, 128: 122.0, 129: 71.0, 130: 140.0, 131: 250.0, 132: 258.0, 133: 225.0, 134: 302.0, 135: 350.0, 136: 318.0, 137: 302.0, 138: 304.0, 139: 98.0, 140: 79.0, 141: 97.0, 142: 76.0, 143: 83.0, 144: 90.0, 145: 90.0, 146: 116.0, 147: 120.0, 148: 108.0, 149: 79.0, 150: 225.0, 151: 250.0, 152: 250.0, 153: 250.0, 154: 400.0, 155: 350.0, 156: 318.0, 157: 351.0, 158: 231.0, 159: 250.0, 160: 258.0, 161: 225.0, 162: 231.0, 163: 262.0, 164: 302.0, 165: 97.0, 166: 140.0, 167: 232.0, 168: 140.0, 169: 134.0, 170: 90.0, 171: 119.0, 172: 171.0, 173: 90.0, 174: 232.0, 175: 115.0, 176: 120.0, 177: 121.0, 178: 121.0, 179: 91.0, 180: 107.0, 181: 116.0, 182: 140.0, 183: 98.0, 184: 101.0, 185: 305.0, 186: 318.0, 187: 304.0, 188: 351.0, 189: 225.0, 190: 250.0, 191: 200.0, 192: 232.0, 193: 85.0, 194: 98.0, 195: 90.0, 196: 91.0, 197: 225.0, 198: 250.0, 199: 250.0, 200: 258.0, 201: 97.0, 202: 85.0, 203: 97.0, 204: 140.0, 205: 130.0, 206: 318.0, 207: 120.0, 208: 156.0, 209: 168.0, 210: 350.0, 211: 350.0, 212: 302.0, 213: 318.0, 214: 98.0, 215: 111.0, 216: 79.0, 217: 122.0, 218: 85.0, 219: 305.0, 220: 260.0, 221: 318.0, 222: 302.0, 223: 250.0, 224: 231.0, 225: 225.0, 226: 250.0, 227: 400.0, 228: 350.0, 229: 400.0, 230: 351.0, 231: 97.0, 232: 151.0, 233: 97.0, 234: 140.0, 235: 98.0, 236: 98.0, 237: 97.0, 238: 97.0, 239: 146.0, 240: 121.0, 241: 80.0, 242: 90.0, 243: 98.0, 244: 78.0, 245: 85.0, 246: 91.0, 247: 260.0, 248: 318.0, 249: 302.0, 250: 231.0, 251: 200.0, 252: 200.0, 253: 140.0, 254: 225.0, 255: 232.0, 256: 231.0, 257: 200.0, 258: 225.0, 259: 258.0, 260: 305.0, 261: 231.0, 262: 302.0, 263: 318.0, 264: 98.0, 265: 134.0, 266: 119.0, 267: 105.0, 268: 134.0, 269: 156.0, 270: 151.0, 271: 119.0, 272: 131.0, 273: 163.0, 274: 121.0, 275: 163.0, 276: 89.0, 277: 98.0, 278: 231.0, 279: 200.0, 280: 140.0, 281: 232.0, 282: 225.0, 283: 305.0, 284: 302.0, 285: 351.0, 286: 318.0, 287: 350.0, 288: 351.0, 289: 267.0, 290: 360.0, 291: 89.0, 292: 86.0, 293: 98.0, 294: 121.0, 295: 183.0, 296: 350.0, 297: 141.0, 298: 260.0, 299: 105.0, 300: 105.0, 301: 85.0, 302: 91.0, 303: 151.0, 304: 173.0, 305: 173.0, 306: 151.0, 307: 98.0, 308: 89.0, 309: 98.0, 310: 86.0, 311: 151.0, 312: 140.0, 313: 151.0, 314: 225.0, 315: 97.0, 316: 134.0, 317: 120.0, 318: 119.0, 319: 108.0, 320: 86.0, 321: 156.0, 322: 85.0, 323: 90.0, 324: 90.0, 325: 121.0, 326: 146.0, 327: 91.0, 328: 97.0, 329: 89.0, 330: 168.0, 331: 70.0, 332: 122.0, 333: 107.0, 334: 135.0, 335: 151.0, 336: 156.0, 337: 173.0, 338: 135.0, 339: 79.0, 340: 86.0, 341: 81.0, 342: 97.0, 343: 85.0, 344: 89.0, 345: 91.0, 346: 105.0, 347: 98.0, 348: 98.0, 349: 105.0, 350: 107.0, 351: 108.0, 352: 119.0, 353: 120.0, 354: 141.0, 355: 145.0, 356: 168.0, 357: 146.0, 358: 231.0, 359: 350.0, 360: 200.0, 361: 225.0, 362: 112.0, 363: 112.0, 364: 112.0, 365: 112.0, 366: 135.0, 367: 151.0, 368: 140.0, 369: 105.0, 370: 91.0, 371: 91.0, 372: 105.0, 373: 98.0, 374: 120.0, 375: 107.0, 376: 108.0, 377: 91.0, 378: 91.0, 379: 91.0, 380: 181.0, 381: 262.0, 382: 156.0, 383: 232.0, 384: 144.0, 385: 135.0, 386: 151.0, 387: 140.0, 388: 97.0, 389: 135.0, 390: 120.0, 391: 119.0}})
fig, ax = plt.subplots()
x_pts = df['Displacement']
y_pts = df['Weight']
ax.scatter(x_pts, y_pts)
ax.set_xlabel('Displacement')
ax.set_ylabel('Weight')
fig

# %%
df.recommendation['Occurrence'][0].to_Altair()

# %%
import altair as alt
visData = pd.DataFrame({'Origin': {0: 'Europe', 1: 'Japan', 2: 'USA'}, 'Record': {0: 68, 1: 79, 2: 245}})\n\nchart = alt.Chart(visData).mark_bar().encode(
    y = alt.Y('Origin', type= 'nominal', axis=alt.Axis(labelOverlap=True, title='Origin')),\n    x = alt.X('Record', type= 'quantitative', title='Number of Records', axis=alt.Axis(title='Number of Records')),\n)\nchart = chart.configure_mark(tooltip=alt.TooltipContent('encoding'))\nchart = chart.configure_title(fontWeight=500,fontSize=13,font='Helvetica Neue')\nchart = chart.configure_axis(titleFontWeight=500,titleFontSize=11,titleFont='Helvetica Neue',\n\t\t\tlabelFontWeight=400,labelFontSize=8,labelFont='Helvetica Neue',labelColor='#505050')\nchart = chart.configure_legend(titleFontWeight=500,titleFontSize=10,titleFont='Helvetica Neue',\n\t\t\tlabelFontWeight=400,labelFontSize=8,labelFont='Helvetica Neue')\nchart = chart.properties(width=160,height=150)\n\nchart

# %% [raw]
# from lux.vis.Vis import Vis
#
# dataset = [
#         {"normal": "USA", "long_var": 3},
#         {"normal": "Europe", "long_var": 3},
#         {"normal": "USA", "long_var": 2},
#         {"normal": "Europe", "long_var": 4},
#     ]
# test = pd.DataFrame(dataset)
# vis = Vis(["long_var", "normal"], test)
# vis

# %%
one_current_vis = lambda ldf: ldf.current_vis is not None and len(ldf.current_vis) == 1

# %%
df = pd.read_csv("../lux/data/car.csv")
df["Year"] = pd.to_datetime(df["Year"], format='%Y') # change pandas dtype for the column "Year" to datetype
# df["Month"] = pd.to_datetime(df["Month"], format='%M') # change pandas dtype for the column "Year" to datetype

df.set_intent([lux.Clause("Year",channel="x"), 
               lux.Clause("Displacement",channel="y"), 
               lux.Clause("Origin=USA")])
# last = get_filter_specs(df.intent)[-1]
# query = df.intent.copy()[0:-1]
# # array of possible values for attribute
# arr = df[last.attribute].unique().tolist()
# query.append(lux.Clause(last.attribute, last.attribute, arr))
# query_vc = VisList(query,df)     
# query_vc

# search_space_vc = VisList(df.current_vis,df)
        
# preprocess(query_vis)
# #for loop to create assign euclidean distance
# recommendation = {"action":"Similarity",
#                                "description":"Show other charts that are visually similar to the Current vis."}
# for vis in search_space_vc:
#     preprocess(vis)
#     vis.score = euclidean_dist(query_vis, vis)
# search_space_vc.normalize_score(invert_order=True)

# %%
lux.register_action("similarity", similar_pattern, one_current_vis)

# %%
df

# %%
df.current_vis
