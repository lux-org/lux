# %%
import pandas as pd
import lux

# %%
df = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
df = pd.DataFrame(df)
df.columns = ['a', 'b', 'c']
df
# Out:
# /Users/ujjaini/Desktop/env/lib/python3.7/site-packages/IPython/core/formatters.py:345: UserWarning:
# Lux defaults to Pandas when there are no valid actions defined.
#   return method()
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
